// %% [markdown]
// ## Table of Contents
// 1. [Section One](#section-one)
// 2. [Section Two](#section-two)
//    * [Sub-section A](#sub-section-a)
// 3. [Section Three](#section-three)
//
// ## Section One
// Content here...
//
// ## Section Two
// Content here...
//
// ### Sub-section A
// Content here...
//
// ## Section Three
// Content here...
//
//
// # Table of Contents
// * [Introduction](#intro)
// * [Exploratory Data Analysis](#eda)
// * [Conclusion](#conclusion)
//
// ---
//
// ## Introduction <a id="intro"></a>
// This is the introduction section.
//
//
//
// # Contoh Penggunaan Markdown
//
// ## Struktur Dasar
//
// - **Heading** menggunakan `#`
// - *Italic* menggunakan `*teks*` atau `_teks_`
// - **Bold** menggunakan `**teks**` atau `__teks__`
// - `Inline code` menggunakan backticks
//
// ## Contoh Format
//
// 1. Heading
// 2. Paragraf
// 3. List
//
// ### Contoh List
//
// - Item pertama
// - Item kedua
//     - Sub-item
// - Item ketiga
//
// ### Contoh Tabel
//
// | Kolom 1 | Kolom 2 | Kolom 3 |
// |--------|--------|--------|
// | A      | B      | C      |
// | 1      | 2      | 3      |
//
// ### Contoh Kode

// %% [markdown]
// ## Exploratory Data Analysis <a id="eda"></a>
// This section contains graphs and data insights.
//
// ## Conclusion <a id="conclusion"></a>
// This is the final summary.

// %%
   
/****************************************************************
*                                                               *
*                          TIPE DATA                            *
*                                                               *
****************************************************************/

// Contoh deklarasi kemudian inisialisasi
// Deklarasi data primitif
int a;
string b;

// Inisialisasi data primitif
a = 100;
b = "Hello World";

// Deklarasi dan inisialisasi variabel dengan tipe data primitif
int integerValue = 100;
long longValue = 100_000_000_000L;
float floatValue = 100.50F;
double doubleValue = 100.50;
decimal decimalValue = 100.50M;
string stringValue = "100";
char charValue = 'A';
bool boolValue = true;



/****************************************************************
*                                                               *
*                              ARRAY                            *
*                                                               *
****************************************************************/

// ==========================================
// BAB 1: Karakteristik Array
// ==========================================
// Array adalah tipe data yang mengumpulkan sekumpulan nilai dalam 1 variabel
// - Tipe nilai array harus sama (int dengan int / string dengan string)
// - Array dihitung dari 0 (mulai dari 0 ya pak!)
// - Ukuran tidak bisa diubah, jika sudah membuat array ukuran 5 (index 0-4). maka tidak bisa diubah saat berjalan (ADA TRIKNYA JIKA MAU DIUBAH)
// - Array cocok digunakan jika sudah tau pasti berapa ukurannya, misal koordinat (X,Y,Z), Jumlah bulan/tahun
// - Performa Array sangatah cepat 


// ==========================================
// BAB 2: Membuat Array
// ==========================================
// Terdapat 3 Array yang umumnya digunakan yaitu
// - Array Biasa
// - Jagged Array
// - Array 2D

// Deklarasi array
int[] intArrayDeklarasi;
int[][] jaggedArrayDeklarasi;
int[,] multiDimArrayDeklarasi;

// Inisialisasi array
intArrayDeklarasi = [1, 2, 3, 4, 5];
jaggedArrayDeklarasi = 
[
[1, 2, 3],
[1, 2],
[3, 4, 5, 6]
];
multiDimArrayDeklarasi = new int[,]
{
{1, 2, 3},
{4, 5, 6},
{7, 8, 9}
};

// Deklarasi dan inisialisasi array
int[] intArray = [1, 2, 3, 4, 5];
decimal[] decimalArray = [1.0M, 2.0M, 3.0M, 4.0M, 5.0M];

// Deklarasi dan inisialisasi array jagged
int[][] jaggedArrayInt =
[
[1, 2, 3],
[1, 2],
[3, 4, 5]
];

// Deklarasi dan inisialisasi array multidimensi
int[,] multiDimArrayInt =
{
{1, 2, 3},
{4, 5, 6},
{7, 8, 9}
};

// KETERANGAN
// ===========================
// - Array 1D (Array dan Jagged Array) dapat menggunakan [] atau new Typedata[] untuk deklarasi dan inisialisasi
// - sedangkan array multidimensi (Array 2D&3D) harus menggunakan new Typedata[,] untuk deklarasi dan inisialisasi.
// 
// - Array 2D menggunakan [,] sedangkan 3D [,,] dst
// - Jagged Array dapat lebih dari [][] seperti [][][] dst


/****************************************************************
*                                                               *
*                              LIST                             *
*                                                               *
****************************************************************/

// ==========================================
// BAB 1: Karakteristik Array
// ==========================================
// List adalah tipe data yang memuat banyak nilai, 

// Deklarasi list
List<int> listIntDeklarasi;
List<List<int>> listDoubleDeklarasi;
BindingList<decimal> bindingListDecimalDeklarasi;
LinkedList<string> linkedListStringDeklarasi;

// Inisialisasi list
listIntDeklarasi = [1, 2, 3, 4, 5];
listDoubleDeklarasi = 
[
[1, 2, 3],
[4, 5],
[7, 8, 9, 10]
];
bindingListDecimalDeklarasi = [10.5M, 20.0M, 35.75M]; // Inisialisasi list dengan tipe data decimal
linkedListStringDeklarasi = new(["Satu", "Dua", "Tiga"]); // Inisialisasi list dengan tipe data string

// Deklarasi dan inisialisasi list
List<int> listInt = [1, 2, 3, 4, 5];
List<decimal> listDecimal = [1.0M, 2.0M, 3.0M, 4.0M, 5.0M];

// Deklarasi dan inisialisasi list dengan tipe data string
Dictionary<int, string> data = new()
{
{1, "satu"},
{2, "dua"},
{3, "tiga"}
};

// ============================================================
// BENCHMARK: List vs LinkedList pakai Stopwatch
// ============================================================

int length = 60000000;
List<int> list = new();
LinkedList<int> linkedList = new();

for (int i = 0; i < length; i++)
{
list.Add(i);
linkedList.AddLast(i);
}

Console.WriteLine($"\n=== Benchmark Contains (data ke-{length}) ===");
Console.WriteLine($"Jumlah data: {length}");

// WARMUP — biar JIT siap
list.Contains(length);
linkedList.Contains(length);

// UKUR LIST
Stopwatch sw = Stopwatch.StartNew();
bool ketemuList = list.Contains(length);
sw.Stop();
Console.WriteLine($"\nList.Contains({length}): {ketemuList}");
Console.WriteLine($"  Milidetik: {sw.ElapsedMilliseconds} ms");
Console.WriteLine($"  Ticks:     {sw.ElapsedTicks}");

// UKUR LINKEDLIST
sw.Restart();
bool ketemuLinked = linkedList.Contains(length);
sw.Stop();
Console.WriteLine($"\nLinkedList.Contains({length}): {ketemuLinked}");
Console.WriteLine($"  Milidetik: {sw.ElapsedMilliseconds} ms");
Console.WriteLine($"  Ticks:     {sw.ElapsedTicks}");
